# %%
import random

number_to_guess = random.randint(1,100)
number_of_attempts = 0

print("Welcome to the number guessing game!\nI'm thinking of a number between 1 to 100.")
choice = (input("Choose a difficulty. Type 'EASY' or 'HARD' : ")).upper()

if choice == 'EASY':
    number_of_attempts = 10

elif choice == 'HARD':
    number_of_attempts = 5

else:
    print("Invalid CHOICE!")
    exit(0)

while(number_of_attempts>0):
    print(f"You have {number_of_attempts} attmpets to guess the number.")
    user_guess = int(input("Enter your Guess : "))
    number_of_attempts-=1

    if user_guess == number_to_guess:
        print(f"YOU GUESSED THE NUMBER!")
        exit(0)
    
    elif user_guess > number_to_guess:
        print("Too HIGH, Guess again.")

    elif user_guess < number_to_guess:
        print("Too LOW, Guess again.")
    
    print('\n')

print("YOU LOST!, Unable to Guess")
# Out:
# Welcome to the number guessing game!
# I'm thinking of a number between 1 to 100.
# Choose a difficulty. Type 'EASY' or 'HARD' :  easy
# You have 10 attmpets to guess the number.
# Enter your Guess :  34
# Too HIGH, Guess again.
#
#
# You have 9 attmpets to guess the number.
# Enter your Guess :  12
# Too LOW, Guess again.
#
#
# You have 8 attmpets to guess the number.
# Enter your Guess :  34
# Too HIGH, Guess again.
#
#
# You have 7 attmpets to guess the number.
# Enter your Guess :  23
# Too LOW, Guess again.
#
#
# You have 6 attmpets to guess the number.
# Enter your Guess :  24
# Too LOW, Guess again.
#
#
# You have 5 attmpets to guess the number.
# Enter your Guess :  25
# YOU GUESSED THE NUMBER!
#
#
# You have 4 attmpets to guess the number.
